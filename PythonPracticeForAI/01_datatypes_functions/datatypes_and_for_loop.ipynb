# %%
revenue = 50
expenses = 10

# %%
type(revenue)
# Out:
# int

# %%
profit = revenue - expenses
profit
# Out:
# 40

# %%
margin = profit * 100 / revenue
margin
# Out:
# 80.0

# %%
type(margin)
# Out:
# float
